# %%
data_comprehensiveness = {
    'Explainer': ['attention', 'attention', 'attention', 'attention', 'attingrad', 'attingrad', 'attingrad', 'attingrad', 
                  'decompx', 'decompx', 'decompx', 'decompx', 'deeplift', 'deeplift', 'deeplift', 'deeplift', 
                  'IxG', 'IxG', 'IxG', 'IxG', 'IG', 'IG', 'IG', 'IG', 
                  'kernelshap', 'kernelshap', 'kernelshap', 'kernelshap', 'lime', 'lime', 'lime', 'lime', 
                  'occlusion', 'occlusion', 'occlusion', 'occlusion', 'random', 'random', 'random', 'random'],
    'Model': ['BERT IMDB', 'BERT Yelp', 'RoBERTa IMDB', 'RoBERTa Yelp', 
              'BERT IMDB', 'BERT Yelp', 'RoBERTa IMDB', 'RoBERTa Yelp', 
              'BERT IMDB', 'BERT Yelp', 'RoBERTa IMDB', 'RoBERTa Yelp', 
              'BERT IMDB', 'BERT Yelp', 'RoBERTa IMDB', 'RoBERTa Yelp', 
              'BERT IMDB', 'BERT Yelp', 'RoBERTa IMDB', 'RoBERTa Yelp', 
              'BERT IMDB', 'BERT Yelp', 'RoBERTa IMDB', 'RoBERTa Yelp', 
              'BERT IMDB', 'BERT Yelp', 'RoBERTa IMDB', 'RoBERTa Yelp', 
              'BERT IMDB', 'BERT Yelp', 'RoBERTa IMDB', 'RoBERTa Yelp', 
              'BERT IMDB', 'BERT Yelp', 'RoBERTa IMDB', 'RoBERTa Yelp',
              'BERT IMDB', 'BERT Yelp', 'RoBERTa IMDB', 'RoBERTa Yelp'],
    'Before': [0.39, 0.54, 0.15, 0.27, 0.41, 0.54, 0.14, 0.28, 0.50, 0.62, 0.22, 0.45, 0.42, 0.55, 0.13, 0.32, 
               0.42, 0.55, 0.13, 0.32, 0.47, 0.62, 0.15, 0.38, 0.49, 0.67, 0.18, 0.39, 0.50, 0.69, 0.18, 0.41, 
               0.45, 0.59, 0.17, 0.37, 0.33, 0.41, 0.13, 0.26],
    'After': [0.58, 0.59, 0.34, 0.27, 0.62, 0.59, 0.33, 0.30, 0.84, 0.70, 0.60, 0.66, 0.63, 0.61, 0.32, 0.41, 
              0.63, 0.61, 0.32, 0.42, 0.76, 0.72, 0.41, 0.56, 0.80, 0.80, 0.48, 0.53, 0.82, 0.84, 0.51, 0.62, 
              0.71, 0.66, 0.42, 0.48, 0.44, 0.38, 0.32, 0.28]
}

# Corrected Data Preparation for Sufficiency
data_sufficiency = {
    'Explainer': ['attention', 'attention', 'attention', 'attention', 'attingrad', 'attingrad', 'attingrad', 'attingrad', 
                  'decompx', 'decompx', 'decompx', 'decompx', 'deeplift', 'deeplift', 'deeplift', 'deeplift', 
                  'IxG', 'IxG', 'IxG', 'IxG', 'IG', 'IG', 'IG', 'IG', 
                  'kernelshap', 'kernelshap', 'kernelshap', 'kernelshap', 'lime', 'lime', 'lime', 'lime', 
                  'occlusion', 'occlusion', 'occlusion', 'occlusion', 'random', 'random', 'random', 'random'],
    'Model': ['BERT IMDB', 'BERT Yelp', 'RoBERTa IMDB', 'RoBERTa Yelp', 
              'BERT IMDB', 'BERT Yelp', 'RoBERTa IMDB', 'RoBERTa Yelp', 
              'BERT IMDB', 'BERT Yelp', 'RoBERTa IMDB', 'RoBERTa Yelp', 
              'BERT IMDB', 'BERT Yelp', 'RoBERTa IMDB', 'RoBERTa Yelp', 
              'BERT IMDB', 'BERT Yelp', 'RoBERTa IMDB', 'RoBERTa Yelp', 
              'BERT IMDB', 'BERT Yelp', 'RoBERTa IMDB', 'RoBERTa Yelp', 
              'BERT IMDB', 'BERT Yelp', 'RoBERTa IMDB', 'RoBERTa Yelp', 
              'BERT IMDB', 'BERT Yelp', 'RoBERTa IMDB', 'RoBERTa Yelp', 
              'BERT IMDB', 'BERT Yelp', 'RoBERTa IMDB', 'RoBERTa Yelp',
              'BERT IMDB', 'BERT Yelp', 'RoBERTa IMDB', 'RoBERTa Yelp'],
    'Before': [0.28, 0.32, 0.12, 0.24, 0.26, 0.31, 0.12, 0.22, 0.18, 0.22, 0.06, 0.14, 0.27, 0.30, 0.13, 0.22, 
               0.26, 0.31, 0.13, 0.22, 0.21, 0.21, 0.09, 0.17, 0.19, 0.20, 0.08, 0.15, 0.19, 0.19, 0.08, 0.15, 
               0.21, 0.24, 0.09, 0.16, 0.34, 0.41, 0.13, 0.26],
    'After': [0.34, 0.24, 0.29, 0.26, 0.29, 0.23, 0.30, 0.20, 0.11, 0.09, 0.08, 0.03, 0.31, 0.21, 0.32, 0.19, 
              0.30, 0.22, 0.32, 0.18, 0.18, 0.05, 0.18, 0.07, 0.13, 0.04, 0.12, 0.04, 0.12, 0.02, 0.11, 0.03, 
              0.16, 0.12, 0.20, 0.06, 0.46, 0.38, 0.32, 0.26]
}

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df_comp = pd.DataFrame(data_comprehensiveness)

# Pivot table for heatmap
df_comp_pivot = df_comp.pivot(index="Explainer", columns="Model", values="Before")
df_comp_pivot_after = df_comp.pivot(index="Explainer", columns="Model", values="After")

# Plotting heatmaps
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(20, 10))
sns.heatmap(df_comp_pivot, annot=True, cmap="YlGnBu", ax=ax1)
sns.heatmap(df_comp_pivot_after, annot=True, cmap="YlGnBu", ax=ax2)
ax1.set_title('Comprehensiveness Before Normalization')
ax2.set_title('Comprehensiveness After Normalization')
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# Create DataFrames
df_suff = pd.DataFrame(data_sufficiency)


# Calculate difference
df_suff['Difference'] = df_suff['After'] - df_suff['Before']

# Pivot table for heatmap
df_suff_pivot = df_suff.pivot(index="Explainer", columns="Model", values="Difference")

# Plotting heatmap
plt.figure(figsize=(20, 10))
heatmap = sns.heatmap(df_suff_pivot, annot=df_suff.pivot(index="Explainer", columns="Model", values="Before").round(2), cmap="YlGnBu", center=0)
heatmap.set_title('Difference in Sufficiency (After - Before) with Before Values Annotated')
plt.show()
