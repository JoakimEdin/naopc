# %%
data_comprehensiveness = {
    'Explainer': ['attention', 'attention', 'attention', 'attention', 'attingrad', 'attingrad', 'attingrad', 'attingrad', 
                  'decompx', 'decompx', 'decompx', 'decompx', 'deeplift', 'deeplift', 'deeplift', 'deeplift', 
                  'IxG', 'IxG', 'IxG', 'IxG', 'IG', 'IG', 'IG', 'IG', 
                  'kernelshap', 'kernelshap', 'kernelshap', 'kernelshap', 'lime', 'lime', 'lime', 'lime', 
                  'occlusion', 'occlusion', 'occlusion', 'occlusion', 'random', 'random', 'random', 'random'],
    'Model': ['BERT IMDB', 'BERT Yelp', 'RoBERTa IMDB', 'RoBERTa Yelp', 
              'BERT IMDB', 'BERT Yelp', 'RoBERTa IMDB', 'RoBERTa Yelp', 
              'BERT IMDB', 'BERT Yelp', 'RoBERTa IMDB', 'RoBERTa Yelp', 
              'BERT IMDB', 'BERT Yelp', 'RoBERTa IMDB', 'RoBERTa Yelp', 
              'BERT IMDB', 'BERT Yelp', 'RoBERTa IMDB', 'RoBERTa Yelp', 
              'BERT IMDB', 'BERT Yelp', 'RoBERTa IMDB', 'RoBERTa Yelp', 
              'BERT IMDB', 'BERT Yelp', 'RoBERTa IMDB', 'RoBERTa Yelp', 
              'BERT IMDB', 'BERT Yelp', 'RoBERTa IMDB', 'RoBERTa Yelp', 
              'BERT IMDB', 'BERT Yelp', 'RoBERTa IMDB', 'RoBERTa Yelp',
              'BERT IMDB', 'BERT Yelp', 'RoBERTa IMDB', 'RoBERTa Yelp'],
    'Before': [0.39, 0.54, 0.15, 0.27, 0.41, 0.54, 0.14, 0.28, 0.50, 0.62, 0.22, 0.45, 0.42, 0.55, 0.13, 0.32, 
               0.42, 0.55, 0.13, 0.32, 0.47, 0.62, 0.15, 0.38, 0.49, 0.67, 0.18, 0.39, 0.50, 0.69, 0.18, 0.41, 
               0.45, 0.59, 0.17, 0.37, 0.33, 0.41, 0.13, 0.26],
    'After': [0.58, 0.59, 0.34, 0.27, 0.62, 0.59, 0.33, 0.30, 0.84, 0.70, 0.60, 0.66, 0.63, 0.61, 0.32, 0.41, 
              0.63, 0.61, 0.32, 0.42, 0.76, 0.72, 0.41, 0.56, 0.80, 0.80, 0.48, 0.53, 0.82, 0.84, 0.51, 0.62, 
              0.71, 0.66, 0.42, 0.48, 0.44, 0.38, 0.32, 0.28]
}

# Corrected Data Preparation for Sufficiency
data_sufficiency = {
    'Explainer': ['attention', 'attention', 'attention', 'attention', 'attingrad', 'attingrad', 'attingrad', 'attingrad', 
                  'decompx', 'decompx', 'decompx', 'decompx', 'deeplift', 'deeplift', 'deeplift', 'deeplift', 
                  'IxG', 'IxG', 'IxG', 'IxG', 'IG', 'IG', 'IG', 'IG', 
                  'kernelshap', 'kernelshap', 'kernelshap', 'kernelshap', 'lime', 'lime', 'lime', 'lime', 
                  'occlusion', 'occlusion', 'occlusion', 'occlusion', 'random', 'random', 'random', 'random'],
    'Model': ['BERT IMDB', 'BERT Yelp', 'RoBERTa IMDB', 'RoBERTa Yelp', 
              'BERT IMDB', 'BERT Yelp', 'RoBERTa IMDB', 'RoBERTa Yelp', 
              'BERT IMDB', 'BERT Yelp', 'RoBERTa IMDB', 'RoBERTa Yelp', 
              'BERT IMDB', 'BERT Yelp', 'RoBERTa IMDB', 'RoBERTa Yelp', 
              'BERT IMDB', 'BERT Yelp', 'RoBERTa IMDB', 'RoBERTa Yelp', 
              'BERT IMDB', 'BERT Yelp', 'RoBERTa IMDB', 'RoBERTa Yelp', 
              'BERT IMDB', 'BERT Yelp', 'RoBERTa IMDB', 'RoBERTa Yelp', 
              'BERT IMDB', 'BERT Yelp', 'RoBERTa IMDB', 'RoBERTa Yelp', 
              'BERT IMDB', 'BERT Yelp', 'RoBERTa IMDB', 'RoBERTa Yelp',
              'BERT IMDB', 'BERT Yelp', 'RoBERTa IMDB', 'RoBERTa Yelp'],
    'Before': [0.28, 0.32, 0.12, 0.24, 0.26, 0.31, 0.12, 0.22, 0.18, 0.22, 0.06, 0.14, 0.27, 0.30, 0.13, 0.22, 
               0.26, 0.31, 0.13, 0.22, 0.21, 0.21, 0.09, 0.17, 0.19, 0.20, 0.08, 0.15, 0.19, 0.19, 0.08, 0.15, 
               0.21, 0.24, 0.09, 0.16, 0.34, 0.41, 0.13, 0.26],
    'After': [0.34, 0.24, 0.29, 0.26, 0.29, 0.23, 0.30, 0.20, 0.11, 0.09, 0.08, 0.03, 0.31, 0.21, 0.32, 0.19, 
              0.30, 0.22, 0.32, 0.18, 0.18, 0.05, 0.18, 0.07, 0.13, 0.04, 0.12, 0.04, 0.12, 0.02, 0.11, 0.03, 
              0.16, 0.12, 0.20, 0.06, 0.46, 0.38, 0.32, 0.26]
}

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_comp = pd.DataFrame(data_comprehensiveness)
df_suff = pd.DataFrame(data_sufficiency)

# Calculate difference
df_comp['Difference'] = df_comp['After'] - df_comp['Before']
df_suff['Difference'] = df_suff['After'] - df_suff['Before']

# Pivot table for heatmap
df_comp_pivot = df_comp.pivot(index="Explainer", columns="Model", values="Difference")
df_comp_labels = df_comp.pivot(index="Explainer", columns="Model", values="Before").round(2)

# Pivot table for heatmap
df_suff_pivot = df_suff.pivot(index="Explainer", columns="Model", values="Difference")
df_suff_labels = df_suff.pivot(index="Explainer", columns="Model", values="Before").round(2)

# Plotting heatmaps side by side
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(30, 12))

sns.heatmap(df_comp_pivot, annot=df_comp_labels, cmap="YlGnBu", center=0, ax=ax1)
ax1.set_title('Difference in Comprehensiveness (After - Before) with Before Values Annotated')

sns.heatmap(df_suff_pivot, annot=df_suff_labels, cmap="YlGnBu_r", center=0, ax=ax2)
ax2.set_title('Difference in Sufficiency (After - Before) with Before Values Annotated')

plt.show()

# %%
# Combine the 'Before' and 'After' into one DataFrame for each metric
df_comp_melted = df_comp.melt(id_vars=['Explainer', 'Model'], value_vars=['Before', 'After'], var_name='Condition', value_name='Comprehensiveness')
df_suff_melted = df_suff.melt(id_vars=['Explainer', 'Model'], value_vars=['Before', 'After'], var_name='Condition', value_name='Sufficiency')

# Sort the explainers by their average 'Before' value for better visualization
explainer_order_comp = df_comp.groupby('Explainer')['Before'].mean().sort_values(ascending=False).index
explainer_order_suff = df_suff.groupby('Explainer')['Before'].mean().sort_values().index

# Plotting the comprehensiveness
fig, ax = plt.subplots(2, 1, figsize=(18, 16), sharex=True)

sns.barplot(x='Explainer', y='Comprehensiveness', hue='Condition', data=df_comp_melted, order=explainer_order_comp, ax=ax[0])
ax[0].set_title('Comprehensiveness Before and After Normalization')
ax[0].set_xlabel('')
ax[0].set_ylabel('Comprehensiveness')
ax[0].legend(title='Condition')

# Plotting the sufficiency
sns.barplot(x='Explainer', y='Sufficiency', hue='Condition', data=df_suff_melted, order=explainer_order_suff, ax=ax[1])
ax[1].set_title('Sufficiency Before and After Normalization')
ax[1].set_xlabel('Explainer')
ax[1].set_ylabel('Sufficiency')
ax[1].legend(title='Condition')

plt.xticks(rotation=45, horizontalalignment='right')
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.lines import Line2D
from matplotlib.colors import LinearSegmentedColormap
import matplotlib.patches as mpatches
import numpy as np

# Data preparation for comprehensiveness and sufficiency
data_comp = {
    'Explainer': ['decompx', 'decompx', 'decompx', 'decompx', 'deeplift', 'deeplift', 'deeplift', 'deeplift', 
                  'IxG', 'IxG', 'IxG', 'IxG', 'IG', 'IG', 'IG', 'IG', 
                  'kernelshap', 'kernelshap', 'kernelshap', 'kernelshap', 'lime', 'lime', 'lime', 'lime', 
                  'occlusion', 'occlusion', 'occlusion', 'occlusion'],
    'Model': ['BERT IMDB', 'BERT Yelp', 'RoBERTa IMDB', 'RoBERTa Yelp', 
              'BERT IMDB', 'BERT Yelp', 'RoBERTa IMDB', 'RoBERTa Yelp', 
              'BERT IMDB', 'BERT Yelp', 'RoBERTa IMDB', 'RoBERTa Yelp', 
              'BERT IMDB', 'BERT Yelp', 'RoBERTa IMDB', 'RoBERTa Yelp', 
              'BERT IMDB', 'BERT Yelp', 'RoBERTa IMDB', 'RoBERTa Yelp', 
              'BERT IMDB', 'BERT Yelp', 'RoBERTa IMDB', 'RoBERTa Yelp', 
              'BERT IMDB', 'BERT Yelp', 'RoBERTa IMDB', 'RoBERTa Yelp'],
    'Comprehensiveness Before': [0.50, 0.62, 0.22, 0.45, 0.42, 0.55, 0.13, 0.32, 
                                 0.42, 0.55, 0.13, 0.32, 0.47, 0.62, 0.15, 0.38, 0.49, 0.67, 0.18, 0.39, 0.50, 0.69, 0.18, 0.41, 
                                 0.45, 0.59, 0.17, 0.37],
    'Comprehensiveness After': [0.84, 0.70, 0.60, 0.66, 0.63, 0.61, 0.32, 0.41, 
                                0.63, 0.61, 0.32, 0.42, 0.76, 0.72, 0.41, 0.56, 0.80, 0.80, 0.48, 0.53, 0.82, 0.84, 0.51, 0.62, 
                                0.71, 0.66, 0.42, 0.48],
    'Sufficiency Before': [0.18, 0.22, 0.06, 0.14, 0.27, 0.30, 0.13, 0.22, 
                           0.26, 0.31, 0.13, 0.22, 0.21, 0.21, 0.09, 0.17, 0.19, 0.20, 0.08, 0.15, 0.19, 0.19, 0.08, 0.15, 
                           0.21, 0.24, 0.09, 0.16],
    'Sufficiency After': [0.11, 0.09, 0.08, 0.03, 0.31, 0.21, 0.32, 0.19, 
                          0.30, 0.22, 0.32, 0.18, 0.18, 0.05, 0.18, 0.07, 0.13, 0.04, 0.12, 0.04, 0.12, 0.02, 0.11, 0.03, 
                          0.16, 0.12, 0.20, 0.06]
}

df = pd.DataFrame(data_comp)

colors = {
    'decompx': 'green', 
    'deeplift': 'red', 
    'IxG': 'purple', 
    'IG': 'brown', 
    'kernelshap': 'pink', 
    'lime': 'gray', 
    'occlusion': 'cyan', 
}

# Function to create scatter plots with arrows
def plot_scatter_with_arrows(df, model, ax):
    model_df = df[df['Model'] == model]
    for _, row in model_df.iterrows():
        # Before point
        ax.scatter(row['Comprehensiveness Before'], row['Sufficiency Before'], color=colors[row['Explainer']], alpha=0.7, marker='s', s=100)
        # After point
        ax.scatter(row['Comprehensiveness After'], row['Sufficiency After'], color=colors[row['Explainer']], edgecolor='black', marker='^', s=100)
        
        # Calculate the difference in coordinates
        dx = row['Comprehensiveness After'] - row['Comprehensiveness Before']
        dy = row['Sufficiency After'] - row['Sufficiency Before']
        
        # Shorten the arrow length to just touch the triangle
        arrow_length = np.sqrt(dx**2 + dy**2) - 0.02  # Adjusting for the head length
        factor = arrow_length / np.sqrt(dx**2 + dy**2)

        # Draw the arrow with dynamic head size
        ax.arrow(row['Comprehensiveness Before'], row['Sufficiency Before'], 
                 dx * factor, dy * factor, 
                 head_width=0.02 * factor, head_length=0.02 * factor, fc=colors[row['Explainer']], ec=colors[row['Explainer']])
    ax.set_title(model)

# Create figure and axes
fig, axs = plt.subplots(2, 2, figsize=(20, 15), sharex=True, sharey=True)

# Create gradient background
def gradient_image(ax, extent):
    x = np.linspace(0, .25, 256)
    y = np.linspace(0, .25, 256)
    X, Y = np.meshgrid(x, y)
    Z = (X + (1 - Y)) / 2  # Adjust gradient to go from top-left to bottom-right
    ax.imshow(Z, extent=extent, origin='lower', aspect='auto', cmap=LinearSegmentedColormap.from_list('gradient', [(1, 1, 1), (0.7, 0.7, 0.7)]))

# Plot each model with gradient background
models = df['Model'].unique()
for ax, model in zip(axs.flatten(), models):
    ax.set_xlim(0, 1)
    ax.set_ylim(0, 0.35)
    extent = [ax.get_xlim()[0], ax.get_xlim()[1], ax.get_ylim()[0], ax.get_ylim()[1]]
    gradient_image(ax, extent)
    plot_scatter_with_arrows(df, model, ax)
    ax.set_xlabel('Comprehensiveness')
    ax.set_ylabel('Sufficiency')
    ax.tick_params(axis='x', which='both', bottom=True, top=False, labelbottom=True)  # Ensure all x-axis tickers are shown

# Create a custom legend
custom_lines = [Line2D([0], [0], color='green', marker='s', linestyle='None', markersize=10, label='decompx'),
                Line2D([0], [0], color='red', marker='s', linestyle='None', markersize=10, label='deeplift'),
                Line2D([0], [0], color='purple', marker='s', linestyle='None', markersize=10, label='IxG'),
                Line2D([0], [0], color='brown', marker='s', linestyle='None', markersize=10, label='IG'),
                Line2D([0], [0], color='pink', marker='s', linestyle='None', markersize=10, label='kernelshap'),
                Line2D([0], [0], color='gray', marker='s', linestyle='None', markersize=10, label='lime'),
                Line2D([0], [0], color='cyan', marker='s', linestyle='None', markersize=10, label='occlusion'),
                Line2D([0], [0], color='grey', marker='s', linestyle='None', markersize=10, label='Before Normalization'),
                Line2D([0], [0], color='grey', marker='^', linestyle='None', markersize=10, label='After Normalization'),
                mpatches.Patch(color='gray', alpha=0.6, label='More Faithful'),]

fig.legend(handles=custom_lines, loc='center right', bbox_to_anchor=(0.86, 0.45), fontsize='small', ncol=5)

plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.lines import Line2D
from matplotlib.colors import LinearSegmentedColormap
import matplotlib.patches as mpatches
import numpy as np

# Data preparation for comprehensiveness and sufficiency
data_comp = {
    'Explainer': ['decompx', 'decompx', 'decompx', 'decompx', 'deeplift', 'deeplift', 'deeplift', 'deeplift', 
                  'IxG', 'IxG', 'IxG', 'IxG', 'IG', 'IG', 'IG', 'IG', 
                  'kernelshap', 'kernelshap', 'kernelshap', 'kernelshap', 'lime', 'lime', 'lime', 'lime', 
                  'occlusion', 'occlusion', 'occlusion', 'occlusion'],
    'Model': [
              'BERT IMDB', 'BERT Yelp', 'RoBERTa IMDB', 'RoBERTa Yelp', 
              'BERT IMDB', 'BERT Yelp', 'RoBERTa IMDB', 'RoBERTa Yelp', 
              'BERT IMDB', 'BERT Yelp', 'RoBERTa IMDB', 'RoBERTa Yelp', 
              'BERT IMDB', 'BERT Yelp', 'RoBERTa IMDB', 'RoBERTa Yelp', 
              'BERT IMDB', 'BERT Yelp', 'RoBERTa IMDB', 'RoBERTa Yelp', 
              'BERT IMDB', 'BERT Yelp', 'RoBERTa IMDB', 'RoBERTa Yelp', 
              'BERT IMDB', 'BERT Yelp', 'RoBERTa IMDB', 'RoBERTa Yelp'],
    'Dataset': [
                'IMDB', 'Yelp', 'IMDB', 'Yelp', 
                'IMDB', 'Yelp', 'IMDB', 'Yelp', 
                'IMDB', 'Yelp', 'IMDB', 'Yelp', 
                'IMDB', 'Yelp', 'IMDB', 'Yelp', 
                'IMDB', 'Yelp', 'IMDB', 'Yelp', 
                'IMDB', 'Yelp', 'IMDB', 'Yelp', 
                'IMDB', 'Yelp', 'IMDB', 'Yelp'],
    'Comprehensiveness Before': [0.50, 0.62, 0.22, 0.45, 0.42, 0.55, 0.13, 0.32, 
                                 0.42, 0.55, 0.13, 0.32, 0.47, 0.62, 0.15, 0.38, 0.49, 0.67, 0.18, 0.39, 0.50, 0.69, 0.18, 0.41, 
                                 0.45, 0.59, 0.17, 0.37],
    'Comprehensiveness After': [0.84, 0.70, 0.60, 0.66, 0.63, 0.61, 0.32, 0.41, 
                                0.63, 0.61, 0.32, 0.42, 0.76, 0.72, 0.41, 0.56, 0.80, 0.80, 0.48, 0.53, 0.82, 0.84, 0.51, 0.62, 
                                0.71, 0.66, 0.42, 0.48],
    'Sufficiency Before': [0.18, 0.22, 0.06, 0.14, 0.27, 0.30, 0.13, 0.22, 
                           0.26, 0.31, 0.13, 0.22, 0.21, 0.21, 0.09, 0.17, 0.19, 0.20, 0.08, 0.15, 0.19, 0.19, 0.08, 0.15, 
                           0.21, 0.24, 0.09, 0.16],
    'Sufficiency After': [0.11, 0.09, 0.08, 0.03, 0.31, 0.21, 0.32, 0.19, 
                          0.30, 0.22, 0.32, 0.18, 0.18, 0.05, 0.18, 0.07, 0.13, 0.04, 0.12, 0.04, 0.12, 0.02, 0.11, 0.03, 
                          0.16, 0.12, 0.20, 0.06]
}

df = pd.DataFrame(data_comp)

# Define colors for explainers
colors = {
    'decompx': 'green', 
    'deeplift': 'red', 
    'IxG': 'purple', 
    'IG': 'brown', 
    'kernelshap': 'pink', 
    'lime': 'gray', 
    'occlusion': 'cyan', 
}

# Function to create scatter plots with arrows
def plot_scatter_with_arrows(df, dataset, ax):
    dataset_df = df[df['Dataset'] == dataset]
    for explainer in dataset_df['Explainer'].unique():
        explainer_df = dataset_df[dataset_df['Explainer'] == explainer]
        for model in explainer_df['Model'].unique():
            model_df = explainer_df[explainer_df['Model'] == model]
            # Before point
            ax.scatter(model_df['Comprehensiveness Before'], model_df['Sufficiency Before'], color=colors[explainer], alpha=0.7, marker='s', s=100)
            # After point
            ax.scatter(model_df['Comprehensiveness After'], model_df['Sufficiency After'], color=colors[explainer], edgecolor='black', marker='^', s=100)
            
            # Calculate the difference in coordinates
            dx = model_df['Comprehensiveness After'].values[0] - model_df['Comprehensiveness Before'].values[0]
            dy = model_df['Sufficiency After'].values[0] - model_df['Sufficiency Before'].values[0]
            
            # Shorten the arrow length to just touch the triangle
            arrow_length = np.sqrt(dx**2 + dy**2) - 0.02  # Adjusting for the head length
            factor = arrow_length / np.sqrt(dx**2 + dy**2)

            # Draw the arrow
            ax.arrow(model_df['Comprehensiveness Before'].values[0], model_df['Sufficiency Before'].values[0], 
                     dx * factor, dy * factor, 
                     head_width=0.02, head_length=0.02, fc=colors[explainer], ec=colors[explainer])
    ax.set_title(f'{dataset} Dataset')

# Create figure and axes
fig, axs = plt.subplots(1, 2, figsize=(20, 14), sharex=True, sharey=True)

# Create gradient background
def gradient_image(ax, extent):
    x = np.linspace(0, .25, 256)
    y = np.linspace(0, .25, 256)
    X, Y = np.meshgrid(x, y)
    Z = (X + (1 - Y)) / 2  # Adjust gradient to go from top-left to bottom-right
    ax.imshow(Z, extent=extent, origin='lower', aspect='auto', cmap=LinearSegmentedColormap.from_list('gradient', [(1, 1, 1), (0.7, 0.7, 0.7)]))

# Plot each dataset with gradient background
for ax, dataset in zip(axs, ['IMDB', 'Yelp']):
    ax.set_xlim(0, 1)
    ax.set_ylim(0, 0.35)
    extent = [ax.get_xlim()[0], ax.get_xlim()[1], ax.get_ylim()[0], ax.get_ylim()[1]]
    gradient_image(ax, extent)
    plot_scatter_with_arrows(df, dataset, ax)
    ax.set_xlabel('Comprehensiveness')
    ax.set_ylabel('Sufficiency')
    ax.tick_params(axis='x', which='both', bottom=True, top=False, labelbottom=True)  # Ensure all x-axis tickers are shown

# Create a custom legend
custom_lines = [Line2D([0], [0], color='green', marker='s', linestyle='None', markersize=15, label='decompx'),
                Line2D([0], [0], color='red', marker='s', linestyle='None', markersize=15, label='deeplift'),
                Line2D([0], [0], color='purple', marker='s', linestyle='None', markersize=15, label='IxG'),
                Line2D([0], [0], color='brown', marker='s', linestyle='None', markersize=15, label='IG'),
                Line2D([0], [0], color='pink', marker='s', linestyle='None', markersize=15, label='kernelshap'),
                Line2D([0], [0], color='gray', marker='s', linestyle='None', markersize=15, label='lime'),
                Line2D([0], [0], color='cyan', marker='s', linestyle='None', markersize=15, label='occlusion'),
                Line2D([0], [0], color='grey', marker='s', linestyle='None', markersize=15, label='Before'),
                Line2D([0], [0], color='grey', marker='^', linestyle='None', markersize=15, label='After'),
                mpatches.Patch(color='gray', alpha=0.6, label='More Faithful'),]

fig.legend(handles=custom_lines, loc='center right', bbox_to_anchor=(0.77, 0.22), fontsize='small', ncol=4)

plt.tight_layout()
plt.show()

# %%
data_comp = {
    'Explainer': ['decompx', 'decompx', 'decompx', 'decompx', 'deeplift', 'deeplift', 'deeplift', 'deeplift', 
                  'IxG', 'IxG', 'IxG', 'IxG', 'IG', 'IG', 'IG', 'IG', 
                  'kernelshap', 'kernelshap', 'kernelshap', 'kernelshap', 'lime', 'lime', 'lime', 'lime', 
                  'occlusion', 'occlusion', 'occlusion', 'occlusion'],
    'Model': [
              'BERT IMDB', 'BERT Yelp', 'RoBERTa IMDB', 'RoBERTa Yelp', 
              'BERT IMDB', 'BERT Yelp', 'RoBERTa IMDB', 'RoBERTa Yelp', 
              'BERT IMDB', 'BERT Yelp', 'RoBERTa IMDB', 'RoBERTa Yelp', 
              'BERT IMDB', 'BERT Yelp', 'RoBERTa IMDB', 'RoBERTa Yelp', 
              'BERT IMDB', 'BERT Yelp', 'RoBERTa IMDB', 'RoBERTa Yelp', 
              'BERT IMDB', 'BERT Yelp', 'RoBERTa IMDB', 'RoBERTa Yelp', 
              'BERT IMDB', 'BERT Yelp', 'RoBERTa IMDB', 'RoBERTa Yelp'],
    'Dataset': [
                'IMDB', 'Yelp', 'IMDB', 'Yelp', 
                'IMDB', 'Yelp', 'IMDB', 'Yelp', 
                'IMDB', 'Yelp', 'IMDB', 'Yelp', 
                'IMDB', 'Yelp', 'IMDB', 'Yelp', 
                'IMDB', 'Yelp', 'IMDB', 'Yelp', 
                'IMDB', 'Yelp', 'IMDB', 'Yelp',
                'IMDB', 'Yelp', 'IMDB', 'Yelp'],
    'Comprehensiveness Before': [0.50, 0.62, 0.22, 0.45, 0.42, 0.55, 0.13, 0.32, 
                                 0.42, 0.55, 0.13, 0.32, 0.47, 0.62, 0.15, 0.38, 0.49, 0.67, 0.18, 0.39, 0.50, 0.69, 0.18, 0.41, 
                                 0.45, 0.59, 0.17, 0.37],
    'Comprehensiveness After': [0.84, 0.70, 0.60, 0.66, 0.63, 0.61, 0.32, 0.41, 
                                0.63, 0.61, 0.32, 0.42, 0.76, 0.72, 0.41, 0.56, 0.80, 0.80, 0.48, 0.53, 0.82, 0.84, 0.51, 0.62, 
                                0.71, 0.66, 0.42, 0.48],
    'Sufficiency Before': [0.18, 0.22, 0.06, 0.14, 0.27, 0.30, 0.13, 0.22, 
                           0.26, 0.31, 0.13, 0.22, 0.21, 0.21, 0.09, 0.17, 0.19, 0.20, 0.08, 0.15, 0.19, 0.19, 0.08, 0.15, 
                           0.21, 0.24, 0.09, 0.16],
    'Sufficiency After': [0.11, 0.09, 0.08, 0.03, 0.31, 0.21, 0.32, 0.19, 
                          0.30, 0.22, 0.32, 0.18, 0.18, 0.05, 0.18, 0.07, 0.13, 0.04, 0.12, 0.04, 0.12, 0.02, 0.11, 0.03, 
                          0.16, 0.12, 0.20, 0.06]
}

# %%
[len(v) for _, v in data_comp.items()]
# Out:
# [28, 28, 28, 32, 28, 28, 28]

# %%
import matplotlib.pyplot as plt
from matplotlib.lines import Line2D
import matplotlib.patches as mpatches
import numpy as np
import pandas as pd
from matplotlib.colors import LinearSegmentedColormap

df = pd.DataFrame(data_comp)

# Define colors for models
colors = {
    'BERT IMDB': 'blue', 
    'BERT Yelp': 'green', 
    'RoBERTa IMDB': 'orange', 
    'RoBERTa Yelp': 'red'
}

# Function to create scatter plots with arrows for each explainer
def plot_scatter_for_explainer(df, explainer, ax):
    explainer_df = df[df['Explainer'] == explainer]
    for model in explainer_df['Model'].unique():
        model_df = explainer_df[explainer_df['Model'] == model]
        # Before point
        ax.scatter(model_df['Comprehensiveness Before'], model_df['Sufficiency Before'], color=colors[model], alpha=0.7, marker='s')
        # After point
        ax.scatter(model_df['Comprehensiveness After'], model_df['Sufficiency After'], color=colors[model], edgecolor='black', marker='^')
        # Shorter Arrow
        ax.arrow(model_df['Comprehensiveness Before'].values[0], model_df['Sufficiency Before'].values[0], 
                 (model_df['Comprehensiveness After'].values[0] - model_df['Comprehensiveness Before'].values[0]) * 0.8, 
                 (model_df['Sufficiency After'].values[0] - model_df['Sufficiency Before'].values[0]) * 0.8, 
                 head_width=0.02, head_length=0.02, fc=colors[model], ec=colors[model])
    ax.set_title(explainer)

# Create figure and axes
explainers = df['Explainer'].unique()
nrows = (len(explainers) + 1) // 2
fig, axs = plt.subplots(nrows, 2, figsize=(20, 14), sharex=True, sharey=True)

# Create gradient background
def gradient_image(ax, extent):
    x = np.linspace(0, .25, 256)
    y = np.linspace(0, .25, 256)
    X, Y = np.meshgrid(x, y)
    Z = (X + (1 - Y)) / 2  # Adjust gradient to go from top-left to bottom-right
    ax.imshow(Z, extent=extent, origin='lower', aspect='auto', cmap=LinearSegmentedColormap.from_list('gradient', [(1, 1, 1), (0.7, 0.7, 0.7)]))

# Plot each explainer with gradient background
for idx, (explainer, ax) in enumerate(zip(explainers, axs.flatten())):
    ax.set_xlim(0, 1)
    ax.set_ylim(0, 0.35)
    extent = [ax.get_xlim()[0], ax.get_xlim()[1], ax.get_ylim()[0], ax.get_ylim()[1]]
    gradient_image(ax, extent)
    plot_scatter_for_explainer(df, explainer, ax)
    if idx < (nrows - 1) * 2:
        ax.set_xlabel('')
    if idx % 2 != 0:
        ax.set_ylabel('')
    ax.tick_params(axis='x', which='both', bottom=True, top=False, labelbottom=True)  # Ensure all x-axis tickers are shown

# Remove empty subplots
for i in range(len(explainers), len(axs.flatten())):
    fig.delaxes(axs.flatten()[i])

# Set x and y labels
for ax in axs[-1, :]:  # Only the bottom row
    ax.set_xlabel('Comprehensiveness')
for ax in axs[:, 0]:  # Only the first column
    ax.set_ylabel('Sufficiency')

# Create a custom legend
custom_lines = [Line2D([0], [0], color='blue', marker='s', linestyle='None', markersize=10, label='BERT IMDB'),
                Line2D([0], [0], color='green', marker='s', linestyle='None', markersize=10, label='BERT Yelp'),
                Line2D([0], [0], color='orange', marker='s', linestyle='None', markersize=10, label='RoBERTa IMDB'),
                Line2D([0], [0], color='red', marker='s', linestyle='None', markersize=10, label='RoBERTa Yelp'),
                Line2D([0], [0], color='grey', marker='s', linestyle='None', markersize=10, label='Before'),
                Line2D([0], [0], color='grey', marker='^', linestyle='None', markersize=10, label='After'),
                mpatches.Patch(color='gray', alpha=0.6, label='More Faithful'),]

fig.legend(handles=custom_lines, loc='center right', bbox_to_anchor=(0.77, 0.22), fontsize='small', ncol=4)

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
from matplotlib.lines import Line2D
import matplotlib.patches as mpatches
import numpy as np
import pandas as pd
from matplotlib.colors import LinearSegmentedColormap

# Assuming data_comp is already defined and populated with your data
df = pd.DataFrame(data_comp)

# Define colors for models
colors = {
    'BERT IMDB': 'blue', 
    'BERT Yelp': 'green', 
    'RoBERTa IMDB': 'orange', 
    'RoBERTa Yelp': 'red'
}

# Function to create scatter plots with arrows for each explainer
def plot_scatter_for_explainer(df, explainer, ax):
    explainer_df = df[df['Explainer'] == explainer]
    for model in explainer_df['Model'].unique():
        model_df = explainer_df[explainer_df['Model'] == model]
        # Before point
        ax.scatter(model_df['Comprehensiveness Before'], model_df['Sufficiency Before'], color=colors[model], alpha=0.7, marker='s')
        # After point
        ax.scatter(model_df['Comprehensiveness After'], model_df['Sufficiency After'], color=colors[model], edgecolor='black', marker='^')

        # Calculate the difference in coordinates
        dx = model_df['Comprehensiveness After'].values[0] - model_df['Comprehensiveness Before'].values[0]
        dy = model_df['Sufficiency After'].values[0] - model_df['Sufficiency Before'].values[0]

        # Shorten the arrow length to just touch the triangle
        arrow_length = np.sqrt(dx**2 + dy**2) - 0.02  # Adjusting for the head length
        factor = arrow_length / np.sqrt(dx**2 + dy**2)

        # Draw the arrow
        ax.arrow(model_df['Comprehensiveness Before'].values[0], model_df['Sufficiency Before'].values[0], 
                 dx * factor, dy * factor, 
                 head_width=0.02, head_length=0.02, fc=colors[model], ec=colors[model])
    ax.set_title(explainer)

# Create figure and axes
explainers = df['Explainer'].unique()
nrows = (len(explainers) + 1) // 2
fig, axs = plt.subplots(nrows, 2, figsize=(20, 14), sharex=True, sharey=True)

# Create gradient background
def gradient_image(ax, extent):
    x = np.linspace(0, .25, 256)
    y = np.linspace(0, .25, 256)
    X, Y = np.meshgrid(x, y)
    Z = (X + (1 - Y)) / 2  # Adjust gradient to go from top-left to bottom-right
    ax.imshow(Z, extent=extent, origin='lower', aspect='auto', cmap=LinearSegmentedColormap.from_list('gradient', [(1, 1, 1), (0.7, 0.7, 0.7)]))

# Plot each explainer with gradient background
for idx, (explainer, ax) in enumerate(zip(explainers, axs.flatten())):
    ax.set_xlim(0, 1)
    ax.set_ylim(0, 0.35)
    extent = [ax.get_xlim()[0], ax.get_xlim()[1], ax.get_ylim()[0], ax.get_ylim()[1]]
    gradient_image(ax, extent)
    plot_scatter_for_explainer(df, explainer, ax)
    if idx < (nrows - 1) * 2:
        ax.set_xlabel('')
    if idx % 2 != 0:
        ax.set_ylabel('')
    ax.tick_params(axis='x', which='both', bottom=True, top=False, labelbottom=True)  # Ensure all x-axis tickers are shown

# Remove empty subplots
for i in range(len(explainers), len(axs.flatten())):
    fig.delaxes(axs.flatten()[i])

# Set x and y labels
for ax in axs[-1, :]:  # Only the bottom row
    ax.set_xlabel('Comprehensiveness')
for ax in axs[:, 0]:  # Only the first column
    ax.set_ylabel('Sufficiency')

# Create a custom legend
custom_lines = [Line2D([0], [0], color='blue', marker='s', linestyle='None', markersize=10, label='BERT IMDB'),
                Line2D([0], [0], color='green', marker='s', linestyle='None', markersize=10, label='BERT Yelp'),
                Line2D([0], [0], color='orange', marker='s', linestyle='None', markersize=10, label='RoBERTa IMDB'),
                Line2D([0], [0], color='red', marker='s', linestyle='None', markersize=10, label='RoBERTa Yelp'),
                Line2D([0], [0], color='grey', marker='s', linestyle='None', markersize=10, label='Before'),
                Line2D([0], [0], color='grey', marker='^', linestyle='None', markersize=10, label='After'),
                mpatches.Patch(color='gray', alpha=0.6, label='More Faithful'),]

fig.legend(handles=custom_lines, loc='center right', bbox_to_anchor=(0.77, 0.22), fontsize='small', ncol=4)

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
from matplotlib.lines import Line2D
import matplotlib.patches as mpatches
import numpy as np
import pandas as pd
from matplotlib.colors import LinearSegmentedColormap

# Assuming data_comp is already defined and populated with your data
df = pd.DataFrame(data_comp)

# Define colors for models
colors = {
    'BERT IMDB': 'blue', 
    'BERT Yelp': 'green', 
    'RoBERTa IMDB': 'orange', 
    'RoBERTa Yelp': 'red'
}

# Function to create scatter plots with arrows for each explainer
def plot_scatter_for_explainer(df, explainer, ax):
    explainer_df = df[df['Explainer'] == explainer]
    for model in explainer_df['Model'].unique():
        model_df = explainer_df[explainer_df['Model'] == model]
        # Before point
        ax.scatter(model_df['Comprehensiveness Before'], model_df['Sufficiency Before'], color=colors[model], alpha=0.7, marker='s', s=100)
        # After point
        ax.scatter(model_df['Comprehensiveness After'], model_df['Sufficiency After'], color=colors[model], edgecolor='black', marker='^', s=100)

        # Calculate the difference in coordinates
        dx = model_df['Comprehensiveness After'].values[0] - model_df['Comprehensiveness Before'].values[0]
        dy = model_df['Sufficiency After'].values[0] - model_df['Sufficiency Before'].values[0]

        # Shorten the arrow length to just touch the triangle
        arrow_length = np.sqrt(dx**2 + dy**2) - 0.02  # Adjusting for the head length
        factor = arrow_length / np.sqrt(dx**2 + dy**2)

        # Draw the arrow
        ax.arrow(model_df['Comprehensiveness Before'].values[0], model_df['Sufficiency Before'].values[0], 
                 dx * factor, dy * factor, 
                 head_width=0.02, head_length=0.02, fc=colors[model], ec=colors[model])
    ax.set_title(explainer)

# Create figure and axes
explainers = df['Explainer'].unique()
nrows = (len(explainers) + 1) // 2
fig, axs = plt.subplots(nrows, 2, figsize=(20, 14), sharex=True, sharey=True)

# Create gradient background
def gradient_image(ax, extent):
    x = np.linspace(0, .25, 256)
    y = np.linspace(0, .25, 256)
    X, Y = np.meshgrid(x, y)
    Z = (X + (1 - Y)) / 2  # Adjust gradient to go from top-left to bottom-right
    ax.imshow(Z, extent=extent, origin='lower', aspect='auto', cmap=LinearSegmentedColormap.from_list('gradient', [(1, 1, 1), (0.85, 0.85, 0.85)]))

# Plot each explainer with gradient background
for idx, (explainer, ax) in enumerate(zip(explainers, axs.flatten())):
    ax.set_xlim(0, 1)
    ax.set_ylim(0, 0.35)
    extent = [ax.get_xlim()[0], ax.get_xlim()[1], ax.get_ylim()[0], ax.get_ylim()[1]]
    gradient_image(ax, extent)
    plot_scatter_for_explainer(df, explainer, ax)
    if idx < (nrows - 1) * 2:
        ax.set_xlabel('')
    if idx % 2 != 0:
        ax.set_ylabel('')
    ax.tick_params(axis='x', which='both', bottom=True, top=False, labelbottom=True)  # Ensure all x-axis tickers are shown

# Remove empty subplots
for i in range(len(explainers), len(axs.flatten())):
    fig.delaxes(axs.flatten()[i])

# Set x and y labels
for ax in axs[-1, :]:  # Only the bottom row
    ax.set_xlabel('Comprehensiveness')
for ax in axs[:, 0]:  # Only the first column
    ax.set_ylabel('Sufficiency')

# Create a custom legend
custom_lines = [Line2D([0], [0], color='blue', marker='s', linestyle='None', markersize=10, label='BERT IMDB'),
                Line2D([0], [0], color='green', marker='s', linestyle='None', markersize=10, label='BERT Yelp'),
                Line2D([0], [0], color='orange', marker='s', linestyle='None', markersize=10, label='RoBERTa IMDB'),
                Line2D([0], [0], color='red', marker='s', linestyle='None', markersize=10, label='RoBERTa Yelp'),
                Line2D([0], [0], color='grey', marker='s', linestyle='None', markersize=10, label='Befor Normalization'),
                Line2D([0], [0], color='grey', marker='^', linestyle='None', markersize=10, label='After Normalization'),
                mpatches.Patch(color='gray', alpha=0.6, label='More Faithful'),]

fig.legend(handles=custom_lines, loc='center right', bbox_to_anchor=(0.80, 0.22), fontsize='small', ncol=4)

plt.tight_layout()
plt.show()
